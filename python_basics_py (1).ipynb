# %% [markdown]
# # pyhton basics
#
# 1.what is python, and why is it popular?
# >- python is a high level,interpreted programming language that is widely used for building software application ,websites,data analysis,machine learning,automationand much more
#
# >-why pyhton is popular
#   -simple and easy to learn
#   -versatile
#   - large community and support
#   -high demand in jobs
#   -extensive libraris and frameworks
#
#   2.what is an interpreter in python?
#   >-an interpreter is a program that executes python code line by line
#   when you write python code (.py file),the interpreter translate it into machine readable instructions so  the computer can run it.
#
#   3.what are predefined key words in python?
#   >-python has a set of predefned keywords that have special meaning and cannot be used as variables name or identifiers.these keywords are used to define the syntax and structure of the language.
#
#   4.can keywords be used as variables names?
#   >-no,keywords can't be used as variables names because it has special meaning in python
#
#   5.what is mutability in python?
#   >-mutability in pyhton refers to the ability of an object to change its state after it is created.
#
#   6.why are lists mutables, but tuple are immutable?
#    >-list in python are mutable because they are designed to be dynamic and flexible  data structures.
#    tuples in python are immutable,meaning their content cannot be modified after creation.
#
#   7.what is the difference between '==' and 'is' operator in pyhton?
#   >- '==' operators is used to check if the values of two objects are equal
#   'is' check if the two variables are refers to the same object in memory
#
# 8.what are logical operator in python?
# >- logical operators in pyhton
#   - and operator-returns true if both conditions are true.
#   -or operator- return true  if ateast one condition is true.
#   -not operator-reverse the results (true -> false,false->true)
#
# 9.what is type casting in pyhton?
#   >- type casting-convert the one data type into another.
#   -there is two type of type casting
#   1-implicit (type conversion)
#   2-explicit (type casting)
#
#
# 10.what is the difference between impicit and explicit type casting.
#  >-#implicit (type conversion)
#     - done automatically by python.
#     - smaller data type-bigger data type( no data loss)
#
#    #explicit (type casting)
#   - done manually by the programmer using built-in-function
#   -common function
#   int()
#   float()
#   str()
#   list()
#   tuple()
#   set()
#   -may cause data loss or error if incompatible.
#
#  11.what is the purpose conditonal statement in pyhton?
#  >-decision making.
#  -control flow.
#  -avoid unnecessary execution.
#  -support multiple choice.
#  -make program interactive.
#
# 12.how does the elif statement work?
# >- elif=else if(meaning)
# -use when you want to check multiple condition after the first (if)
# - pyhton checks condition from top to bottom.
# -as soon as one condition is true, the corresponding block runs and the rest are skipped.
# -elif must follow an if.
#
# 13.what is the difference between for and while loops?
# >- for loops-when you know how many times you want to repeat.
#   - work with sequence(list,tuples,string,range etc)
#   -iteration variable is automatically handled by pyhton.
#   -less chance of infinite loop( ends automatically when sequence ends).
#
# -while loops-used when you don't know the number is iterations in advance and want to loop until a condition becomes false.
#  -work with a condition.
#  -you must intialize and update the variable manually.
#  - higher chance  to become infinite loop if condition never become false.
#
# 14.describe a scenario where a while loop is more suitable than a for loop.
#
#  >l- while loop is more suitable than a for loop where...
# -unknown number of iterations-
#    the user can perform any number of transcations.
# -conditional termination-
#      the loop terminates when the user choosen to exit.
# -dynamic user input-
#    the user's chices and actions determine the flow of the program.

# %%
# 1- wap a python program to print"hello world"
print("hello world")


#  2-wap a python program that displays your name and age
name="abhishek vashiht"
age=21
print( name)
print(age)

#  3- write code to print all the predefined keywords in pyhton using the keywords libraries.
import keyword
print(keyword.kwlist)

# 4-wap to checks if a given words is a python keyword
import keyword

word = input("Enter a word: ")

if keyword.iskeyword(word):
    print(f" '{word}' is a Python keyword")
else:
    print(f" '{word}' is NOT a Python keyword")

# 5-create a list and tuple in python,and demonstrate how attempting to change an element works differently for each.
my_list = [10, 20, 30]
print("Original List:", my_list)

#  Changing an element in list
my_list[1] = 99
print("Modified List:", my_list)

# Creating a Tuple
my_tuple = (10, 20, 30)
print("Original Tuple:", my_tuple)


# Trying to change an element in tuple
try:
    my_tuple[1] = 99   # This will cause an error
except TypeError as e:
    print("Error when modifying tuple:", e)

# # 6-write a function to demonstrate the behaviour of mutable and immutable arguements.
   #- i have not studied about functions yet.

# 7-. Write a program that performs basic arithmetic operations on two user-input numbers.
a=int(input("enter the num 1"))
b=int(input("enter the num 2"))
print("sum",a+b)
print("subtraction",a-b)
print("multiplication",a*b)
print("division",a/b)
print("modulus",a%b)

# 8- Write a program to demonstrate the use of logical operators.
x=10
y=5

print(x > 5 and y < 10)   # AND
print(x > 5 or y > 10)    # OR
print(not(x > 5))         # NOT

# 9-Write a Python program to convert user input from string to integer, float, and boolean types.
a=input("enter the num")
print(int(a))
print(float(a))
print(bool(a))

# 10-Write code to demonstrate type casting with list elements.
str_list = ["10", "20", "30"]

print("To int:", [int(x) for x in str_list])
print("To float:", [float(x) for x in str_list])
print("To str:", [str(x) for x in [10, 20, 30]])

# 11-Write a program that checks if a number is positive, negative, or zero
num=int(input("enter the num"))
if num>0:
  print("positive")
elif num<0:
  print("negative")
else:
    print("zero")

# 12-Write a for loop to print numbers from 1 to 10.

for a in range(1,11):
  print(a)

# 13- Write a Python program to find the sum of all even numbers between 1 and 50
total = 0

for i in range(2, 51, 2):  # start=2, end=50, step=2
    total += i

print("Sum of even numbers between 1 and 50 is:", total)

# 14-Write a program to reverse a string using a while loop.
text = input("Enter a string: ")
reversed_str = ""

i = len(text) - 1   # start from last index

while i >= 0:
    reversed_str += text[i]
    i -= 1

print("Reversed string:", reversed_str)

# 15-Write a Python program to calculate the factorial of a number provided by the user using a while loop.
num = int(input("Enter a number: "))
factorial = 1
i = 1

while i <= num:
    factorial *= i
    i += 1

print(f"Factorial of {num} is {factorial}")
# Out:
# hello world
# abhishek vashiht
# 21
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# Enter a word: ji
#  'ji' is NOT a Python keyword
# Original List: [10, 20, 30]
# Modified List: [10, 99, 30]
# Original Tuple: (10, 20, 30)
# Error when modifying tuple: 'tuple' object does not support item assignment
